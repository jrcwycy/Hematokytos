# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import h5py
import scipy.sparse as sp
import yaml
import time
import gget
from scipy.stats import zscore

import anndata as an
import scanpy as sc
import rapids_singlecell as rsc
import scvi
from matplotlib.colors import LinearSegmentedColormap
from adjustText import adjust_text

from matplotlib.cm import ScalarMappable
from matplotlib.colors import Normalize
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.patheffects as path_effects

sc.settings.verbosity = 2

# %% [markdown]
# # Load in data

# %%
# %%time
# h5ad built in Hematokytos/anndatas/integrate_scfib_ihsc.ipynb
fpath = "/nfs/turbo/umms-indikar/shared/projects/HSC/updated_adata/fib_ihsc_processed.h5ad"

adata = sc.read_h5ad(fpath)
adata.X = adata.layers['log_norm'].copy()
adata
# Out:
# CPU times: user 921 ms, sys: 2.87 s, total: 3.79 s
# Wall time: 7.47 s
# AnnData object with n_obs × n_vars = 15317 × 23434
#     obs: 'batch', 'barcoded_phase', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'outlier', 'mt_outlier', 'S_score', 'G2M_score', 'phase', 'leiden', 'cluster_str', 'cluster'
# ...

# %% [markdown]
# # FA plot by cluster

# %%
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = 4, 4

sc.pl.draw_graph(
    adata,
    color=['cluster'],
    size=25,
    ncols=1,
    add_outline=True,
    outline_color=('k', 'k'),
    frameon=False,
    alpha=1,
    title='',
    legend_loc='none',
)

# %% [markdown]
# # FA plot by library

# %%
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = 4, 4

sc.pl.draw_graph(
    adata,
    color=['batch'],
    size=25,
    ncols=1,
    add_outline=True,
    outline_color=('k', 'k'),
    frameon=False,
    alpha=1,
    title='',
    legend_loc='none',
    palette=['Grey', 'deepskyblue'],
)

# %% [markdown]
# # Cell counts

# %%
# Prepare data and sort by count descending
batch_counts = adata.obs['batch'].value_counts().reset_index()
batch_counts.columns = ['batch', 'count']
batch_counts = batch_counts.reset_index(drop=True)

print(batch_counts)

# Transposed horizontal barplot with largest bar on top
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = 4, 1.2

sns.barplot(
    data=batch_counts,
    y='batch',
    x='count',
    ec='k',
    hue='batch',
    legend=False,
    width=0.6,
    palette=['Grey', 'deepskyblue']  # first = largest
)

plt.gca().invert_yaxis()
plt.ylabel("")
plt.xlabel("cells", fontsize=12)
plt.xticks(fontsize=11)

plt.gca().set_yticklabels(['library 2', 'library 1'], fontsize=12)
plt.margins(y=0.18)

sns.despine()
plt.tight_layout()
plt.show()
# Out:
#   batch  count
# 0   hsc   8357
# 1   fib   6960

# %% [markdown]
# ## spike-ins removed

# %%
# remove spike-in controls
adata.obs['batch_clean'] = adata.obs['batch'].copy()
adata.obs['batch_clean'] = adata.obs['batch_clean'].astype('str')

# identify hsc cells in control clusters
mask = (adata.obs['batch'] == 'hsc') & (adata.obs['cluster'].isin(['C4', 'C5']))
# label them as NaN
adata.obs.loc[mask, 'batch_clean'] = 'spike-ins'

adata.obs['batch_clean'] = adata.obs['batch_clean'].astype('category')

print(adata.obs['batch_clean'].value_counts(sort=False))
# Out:
# batch_clean
# fib          6960
# hsc          6849
# spike-ins    1508
# Name: count, dtype: int64

# %%
# Total counts per original batch
batch_totals = adata.obs['batch'].value_counts()

# Spike-in counts (only exist within hsc)
spike_counts = (
    adata.obs
    .query("batch_clean == 'spike-ins'")
    .groupby('batch', observed=True)
    .size()
)

# Non–spike-in hsc
hsc_spike = spike_counts.get('hsc', 0)
hsc_non_spike = batch_totals['hsc'] - hsc_spike

# Fib has no spike-ins
fib_total = batch_totals['fib']

labels = ['library 1', 'library 2']   # fib, hsc (top to bottom)
y_pos = [0, 1]

# Bar segments
fib_vals = [fib_total, 0]
hsc_main = [0, hsc_non_spike]
hsc_spike_vals = [0, hsc_spike]

plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = (4, 1.2)

fig, ax = plt.subplots()

# HSC (library 1) – non–spike portion
ax.barh(
    y=0,
    width=hsc_non_spike,
    color='deepskyblue',
    edgecolor='k',
    height=0.6
)

# HSC spike-in portion
ax.barh(
    y=0,
    width=hsc_spike,
    left=hsc_non_spike,
    color='lightcoral',
    edgecolor='k',
    height=0.6
)

# Fib (library 2)
ax.barh(
    y=1,
    width=fib_total,
    color='grey',
    edgecolor='k',
    height=0.6
)

# Formatting
ax.set_yticks(y_pos)
ax.set_yticklabels(labels, fontsize=12)
ax.set_xlabel("cells", fontsize=12)
ax.invert_yaxis()
ax.margins(y=0.18)

sns.despine()
plt.tight_layout()
plt.show()

# %%
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = 4, 4

sc.pl.draw_graph(
    adata,
    color=['batch_clean'],
    size=25,
    ncols=1,
    add_outline=True,
    outline_color=('k', 'k'),
    frameon=False,
    alpha=1,
    title='',
    legend_loc='none',
    palette=['Grey', 'deepskyblue', 'lightcoral'],
)

# %% [markdown]
# # FA plots with gene expression

# %%
low = '#131317' # dark
mid = '#3B80EB' # blue
high = '#F2D123' # yellow

custom_cmap = LinearSegmentedColormap.from_list(
    "custom_cmap",
    [(0.0, low), (0.15, low), (0.5, mid), (0.85, high), (1.0, high)]
)


genes_to_plot = [
    'COL1A1', 'PRRX1', 'DCN',
    'ITGA6', 'ACE', 'PECAM1', 
    'CD34', 'REL', 'CD9',#'SPINK2',
]

genes_to_plot = [g for g in genes_to_plot if g in adata.var_names]

plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = 2, 2.5

sc.pl.draw_graph(
    adata,
    color=genes_to_plot,
    size=25,
    ncols=3,
    add_outline=True,
    cmap=custom_cmap,
    outline_color=('k', 'k'),
    frameon=False,
    alpha=1,
    colorbar_loc=None,
    use_raw=False,
    layer='log_norm',
    # legend_loc='none',
)

# %% [markdown]
# # Percent expressing (markers)

# %%
query  = [
    'STAT5A',
    'REL',
    'FOS',
    'GATA2',
    'CD34',
    'ETS2',
    'MSI2',
    'RUNX2',
    'ACE',
    'PECAM1',
    'MECOM', 
    'ETV6',
    'DCN',
    'LUM',
    'FTL',
    'COL1A1',
]

query = [g for g in query if g in adata.var_names]
pdf = adata[:, query].to_df(layer='raw_counts')
pdf['cluster_str'] = adata.obs['cluster_str']
pdf['batch'] = adata.obs['batch']

for q in query:
    pdf[f'{q}+'] = pdf[q] > 0

# print(pdf.tail().to_string())

# calculate % q+ by gene and batch
plot_df = (
    pdf.groupby('batch', observed=True)[[f'{q}+' for q in query]]
    .mean()
    .T * 100  # convert to percent
)

plot_df.index = [gene.replace('+', '') for gene in plot_df.index]  # clean labels

plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = 6, 2.5


plot_df.plot(
    kind='bar',
    ec='k',
    lw=0.75,
    color=['Grey', 'deepskyblue'],
)
plt.ylabel('% non-zero')
plt.legend(title='Batch', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
sns.despine()

plt.gcf().patch.set_facecolor('none') 
plt.gca().set_facecolor('none')         
plt.show()

# %%
pdf = adata[:, query].to_df(layer='raw_counts')
pdf['cluster_str'] = adata.obs['cluster_str']
pdf['batch'] = adata.obs['batch_clean']

for q in query:
    pdf[f'{q}+'] = pdf[q] > 1

plot_df = (
    pdf.groupby('batch', observed=True)[[f'{q}+' for q in query]]
    .mean()
    .T * 100  # Convert to percent
)

plot_df.index = [gene.replace('+', '') for gene in plot_df.index]  # Clean labels

plot_df
# Out:
# batch          fib        hsc   spike-ins
# STAT5A    0.359195   1.795883    0.729443
# REL       2.500000  41.100891    2.387268
# FOS      58.635057  50.343116    2.387268
# GATA2     9.741379  11.665937    1.326260
# CD34      0.028736  11.038108    0.066313
# ETS2      3.477011  14.600672    1.856764
# MSI2      2.428161  24.397722    3.448276
# RUNX2     2.169540  12.162359   10.610080
# ACE       0.172414   3.387356    0.198939
# PECAM1    0.000000   3.080742    0.066313
# MECOM     0.474138   1.007446    0.663130
# ETV6      1.795977   7.154329   16.246684
# DCN      99.497126  11.724339   98.408488
# LUM      94.209770   8.628997   96.220159
# FTL      99.985632  99.853993  100.000000
# COL1A1  100.000000  99.196963   99.668435

# %% [markdown]
# # Marker genes

# %% [markdown]
# ## Load genes

# %%
def load_pathway(fpath):
    """
    Loads an Enrichr-like database file into a boolean DataFrame.

    Args:
        fpath (str): Path to the Enrichr-like database file.

    Returns:
        pandas.DataFrame: A boolean DataFrame where:
            - Index: Genes
            - Columns: Pathways
            - Values: True if the gene is in the pathway, False otherwise.
    """

    result = []
    with open(fpath,  encoding='utf-8') as f:
        for line in f:
            split_line = [x for x in line.strip().split('\t') if x]  # Remove empty strings directly

            row = {'label': split_line[0]}
            for gene in split_line[1:]:
                row[gene] = 1

            result.append(row)

    df = pd.DataFrame(result)
    df = df.fillna(0.0).set_index('label').astype(bool).T  # Chained operations for clarity

    return df

fpath = "../resources/PanglaoDB_Augmented_2021.txt"
marker_mat = load_pathway(fpath)
# filter for certain cell types
cell_types = ['Hematopoietic Stem Cells', 'Endothelial Cells', 'Fibroblasts']

marker_mat = marker_mat[marker_mat[cell_types].any(axis=1)][cell_types]
marker_mat = marker_mat[marker_mat.index.isin(adata.var_names)]

print(f"Raw: {marker_mat.shape=}")
marker_mat.head()
# Out:
# Raw: marker_mat.shape=(444, 3)
# label    Hematopoietic Stem Cells  Endothelial Cells  Fibroblasts
# RARRES2                     False              False         True
# CELA1                       False              False         True
# ANPEP                        True              False        False
# KLK1                        False               True        False
# RNASE1                       True               True        False

# %% [markdown]
# ## DGE

# %%
# remove spike-in controls
adata.obs['cluster_clean'] = adata.obs['cluster'].copy()

# identify hsc cells in control clusters
mask = (adata.obs['batch'] == 'hsc') & (adata.obs['cluster'].isin(['C4', 'C5']))
# label them as NaN
adata.obs.loc[mask, 'cluster_clean'] = np.nan

adata.obs['cluster_clean'] = adata.obs['cluster_clean'].astype('category')

print(adata.obs['cluster_clean'].value_counts(sort=False))
# Out:
# cluster_clean
# C4    3262
# C5    3694
# R1    1986
# R2    4343
# R3     524
# Name: count, dtype: int64

# %%
mapping = {
    'R1': 'reprogramming',
    'R2': 'reprogramming',
    'R3': 'reprogramming',
    'C4': 'control',
    'C5': 'control',
}

adata.obs['group_clean'] = adata.obs['cluster_clean'].map(mapping)

sc.tl.rank_genes_groups(
    adata, 
    groupby='group_clean',
    method='wilcoxon',
    layer='log_norm',
    use_raw=False,
    pts=True,
)

deg = sc.get.rank_genes_groups_df(
    adata, 
    group=None,
    pval_cutoff=0.05,
)

deg.head()
# Out:
# ranking genes
# ... storing 'group_clean' as categorical
#     finished (0:00:39)
#      group    names      scores  logfoldchanges  pvals  pvals_adj  \
# 0  control  MT-ATP8  106.620018        5.162133    0.0        0.0
# 1  control    ISG15  105.862289        4.775931    0.0        0.0
# 2  control  MT-ND4L  104.138985        3.476631    0.0        0.0
# 3  control   TSPAN9  103.801674        2.060074    0.0        0.0
# 4  control      MX1  103.748672        6.226389    0.0        0.0
#
#    pct_nz_group  pct_nz_reference
# 0      1.000000          0.508791
# 1      0.999856          0.652554
# 2      0.998131          0.645258
# 3      1.000000          0.980026
# 4      0.988212          0.079058

# %%
# Define thresholds
max_padj = 0.05

for column in marker_mat:

    gene_list = marker_mat[marker_mat[column]].index
    print(f"{column}")
    print(f"\t{len(gene_list)} genes")

    gdf = deg[deg['names'].isin(gene_list)]
    
    plt.rcParams['figure.dpi'] = 150
    plt.rcParams['figure.figsize'] = 3.5, 1.5
    
    # Sort by fold change
    gdf = gdf.sort_values('logfoldchanges')
    gdf = gdf[gdf['group'] == 'control']
    gdf = gdf[gdf['logfoldchanges'].abs() < 12]
    
    # Manually create jittered y-values
    gdf['y_jitter'] = np.random.normal(loc=0, scale=0.1, size=len(gdf))
    
    # Plot with scatterplot
    fig, ax = plt.subplots(figsize=(6, 3.25), dpi=150)
     # Create scatter plot with color-mapped points
    sc = ax.scatter(
        gdf['logfoldchanges'],
        gdf['y_jitter'],
        c=gdf['logfoldchanges'],
        cmap='bwr',
        edgecolor='k',
        linewidth=0.5,
        s=5,
    )

    # Add colorbar to the middle right
    cbar = fig.colorbar(sc, ax=ax, orientation='vertical', pad=0.05, fraction=0.05, shrink=0.65,)
    cbar.set_label('Log Fold Change', fontsize=8)

    # Continue with annotation and styling
    texts = []
    target_x = []
    target_y = []
    for _, row in gdf[abs(gdf['logfoldchanges']) > 2].iterrows():
        txt = ax.text(
                row['logfoldchanges'],
                row['y_jitter'],
                row['names'],
                fontsize=6,
                ha='center',
                va='bottom',
                zorder=4
        )
        txt.set_path_effects([
            path_effects.Stroke(linewidth=2, foreground='white', alpha=0.8),  # White outline
            path_effects.Normal()
        ])
        texts.append(txt)
        target_x.append(row['logfoldchanges'])
        target_y.append(row['y_jitter'])        
        
    adjust_text(
        texts,
        target_x=target_x,
        target_y=target_y,
        expand_text=(0, 10),#(0, 10),
        avoid_self=True,
        ax=ax,
        arrowprops=dict(arrowstyle='-', lw=0.3, color='gray'),
        force_points=(0.75, 0.75),
        # force_text=(0.75, 0.75),
    )

    ax.axvline(x=0, c='k', lw=0.75, ls='--', zorder=0)
    ax.set_xlabel('Fold change (log)')
    ax.set_ylabel('')
    ax.set_yticks([])
    ax.set_title(f"{column[:-1]} Genes", y=1.25, fontsize=10)

    ax.text(0.01, 1.15, "up in reprogram", transform=ax.transAxes,
            ha='left', va='top', fontsize=10)

    ax.text(0.99, 1.15, "up in control", transform=ax.transAxes,
            ha='right', va='top', fontsize=10)

    sns.despine(left=True)
    fig.tight_layout()
    plt.show()
# Out:
# 2026-08-05 14:34:14 | [WARNING] Looks like you are using a tranform that doesn't support FancyArrowPatch, using ax.annotate instead. The arrows might strike through texts. Increasing shrinkA in arrowprops might help.
# Hematopoietic Stem Cells
# 	117 genes
# Endothelial Cells
# 	190 genes
# Fibroblasts
# 	215 genes

# %%
query  = [
    'STAT5A',
    'REL',
    'FOS',
    'GATA2',
    'CD34',
    # 'PROCR',
    'ETS2',
    # 'HHEX',
    'MSI2',
    # 'RUNX2',
    'G0S2',
    'ACE',
    'PECAM1',
    # 'MECOM', 
    # 'PDPN',
    'PODXL',
    'ETV6',
    'DCN',
    'LUM',
    'FTL',
    'COL1A1',
]

group_col = 'plot_group'

query = [g for g in query if g in adata.var_names]
pdf = adata[:, query].to_df(layer='raw_counts')
pdf['group_clean'] = adata.obs['group_clean']
pdf['batch'] = adata.obs['batch']


mapping = {
    'control': 'fib',
    'reprogramming': 'hsc',
}

pdf['plot_group'] = pdf['group_clean'].map(mapping)

# pdf.head()
for q in query:
    pdf[f'{q}+'] = pdf[q] > 0

# print(pdf.tail().to_string())

# calculate % q+ by gene and batch
plot_df = (
    pdf.groupby(group_col, observed=True)[[f'{q}+' for q in query]]
    .mean()
    .T * 100  
)

plot_df.index = [gene.replace('+', '') for gene in plot_df.index]  

plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = 6, 2.5

plot_df.plot(
    kind='bar',
    ec='k',
    lw=0.75,
    color=['Grey', 'deepskyblue'],
)
plt.ylabel('% non-zero')
plt.legend(title='Batch', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
sns.despine()

plt.gcf().patch.set_facecolor('none') 
plt.gca().set_facecolor('none')         
plt.show()
