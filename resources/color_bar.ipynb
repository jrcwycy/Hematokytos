# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# %%
cmap = plt.cm.viridis
norm = mpl.colors.Normalize(vmin=0, vmax=1)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1.05, 2
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([0, 1])
cbar.set_ticklabels(['low', 'high'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('expression', rotation=90, labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
cmap = plt.cm.viridis
norm = mpl.colors.Normalize(vmin=0, vmax=1)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 2.5, 0.83
fig, ax = plt.subplots()

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='horizontal',
)

cbar.set_ticks([0, 1])
cbar.set_ticklabels(['low', 'high'])
cbar.ax.tick_params(labelsize=11)
cbar.set_label('expression', labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
low = '#131317' # dark   #424251
mid = '#3B80EB' # blue
high = '#F2D123' # yellow

custom_cmap = LinearSegmentedColormap.from_list(
    "custom_cmap",
    [(0.0, low), (0.15, low), (0.5, mid), (0.85, high), (1.0, high)]
)

norm = mpl.colors.Normalize(vmin=0, vmax=1)
sm = plt.cm.ScalarMappable(cmap=custom_cmap, norm=norm)
sm.set_array([])

# --- Figure and colorbar settings ---
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 2.75, 0.85
fig, ax = plt.subplots()

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='horizontal',
    # shrink=0.5,
)

# --- Label and formatting ---
cbar.set_ticks([0, 1])
cbar.set_ticklabels(['low', 'high'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('Expression', labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
vmin = -2
vmax = 2

cmap = plt.cm.bwr
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1.07, 2
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([vmin, vmax])
cbar.set_ticklabels([f'≤ {vmin}', f'≥ {vmax}'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('log$_2$ fold change', rotation=90, labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
vmin = -2
vmax = 2

cmap = plt.cm.bwr
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1.07, 1.75
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([vmin, vmax])
cbar.set_ticklabels([f'≤ {vmin}', f'≥ {vmax}'])
cbar.ax.tick_params(labelsize=11)
cbar.set_label('log$_2$FC', rotation=90, labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
vmin = -2
vmax = 2

cmap = plt.cm.RdBu_r
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1, 3
fig, ax = plt.subplots()

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([vmin, -1, 0, 1, vmax])
# cbar.set_ticklabels([vmin, f'≥ {vmax}'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('expression (z-score)', rotation=90, labelpad=3, fontsize=12)

plt.tight_layout()
plt.show()

# %%
# low = '#424251' #'#131317' # dark
# mid = '#3B80EB' # blue
# high = '#F2D123' # yellow

low = '#131317' # dark
mid = '#3B80EB' # blue
high = '#F2D123' # yellow

custom_cmap = LinearSegmentedColormap.from_list(
    "custom_cmap",
    [(0.0, low), (0.15, low), (0.5, mid), (0.85, high), (1.0, high)]
)

vmin = -5
vmax = 5

norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=custom_cmap, norm=norm)
sm.set_array([])

# --- Figure and colorbar settings ---
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 2.5, 0.85
fig, ax = plt.subplots()

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='horizontal',
)

cbar.set_ticks([vmin, vmax])
cbar.set_ticklabels([f'≤ {vmin}', f'≥ {vmax}'])
cbar.ax.tick_params(labelsize=11)
cbar.set_label('log$_2$FC', labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
vmin = -5
vmax = 5

cmap = plt.cm.bwr
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 2.5, 1
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='horizontal',
    shrink=0.5,
)

cbar.set_ticks([vmin, vmax])
cbar.set_ticklabels([f'≤ {vmin}', f'≥ {vmax}'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('log$_2$ fold change', rotation=0, labelpad=10, fontsize=12)

plt.tight_layout()
plt.show()

# %%
cmap = plt.cm.inferno
# cmap = plt.cm.viridis
norm = mpl.colors.Normalize(vmin=0, vmax=1)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 0.9, 2.5
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.3,
)

cbar.set_ticks([0, 1])
cbar.set_ticklabels(['early', 'late'])
cbar.ax.tick_params(labelsize=11)
cbar.set_label('')


plt.tight_layout()
plt.show()

# %%
vmin = -2
vmax = 2

low = '#131317' # dark
mid = '#3B80EB' # blue
high = '#F2D123' # yellow

custom_cmap = LinearSegmentedColormap.from_list(
    "custom_cmap",
    [(0.0, low), (0.15, low), (0.5, mid), (0.85, high), (1.0, high)]
)

norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=custom_cmap, norm=norm)
sm.set_array([])


plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1, 3
fig, ax = plt.subplots()

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([vmin, -1, 0, 1, vmax])
# cbar.set_ticklabels([vmin, f'≥ {vmax}'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('expression (z-score)', rotation=90, labelpad=3, fontsize=12)

plt.tight_layout()
plt.show()

# %%
vmin = 0
vmax = 1

low = '#131317' # dark
mid = '#3B80EB' # blue
high = '#F2D123' # yellow

custom_cmap = LinearSegmentedColormap.from_list(
    "custom_cmap",
    [(0.0, low), (0.15, low), (0.5, mid), (0.85, high), (1.0, high)]
)

norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=custom_cmap, norm=norm)
sm.set_array([])


plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1.05, 2
fig, ax = plt.subplots()

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([0, 1])
cbar.set_ticklabels(['low', 'high'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('expression', rotation=90, labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
vmin = 0
vmax = 1

cmap = plt.cm.Reds
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1, 2
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([vmin, vmax])
cbar.set_ticklabels([vmin, vmax])
cbar.ax.tick_params(labelsize=11)
cbar.set_label('mean expression', rotation=90, labelpad=15, fontsize=12)

plt.tight_layout()
plt.show()

# %%
vmin = 0
vmax = 1

cmap = plt.cm.Reds
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 2.2, 1
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='horizontal',
    shrink=0.5,
)

cbar.set_ticks([vmin, vmax])
cbar.set_ticklabels([vmin, vmax])
cbar.ax.tick_params(labelsize=11)
cbar.set_label('mean expression', rotation=0, labelpad=12, fontsize=12)

plt.tight_layout()
plt.show()

# %%
cmap = plt.cm.RdYlBu_r
norm = mpl.colors.Normalize(vmin=-1, vmax=1)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1.15, 2
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([-1, 0, 1])
# cbar.set_ticklabels(['–', 0, '+'])
cbar.set_ticklabels(['down', 0, 'up'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('velocity', rotation=90, labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
vmin = -1.5
vmax = 1.5

cmap = plt.cm.PuOr
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1.15, 2.5
fig, ax = plt.subplots()

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([vmin, 0, vmax])
# cbar.set_ticklabels([vmin, f'≥ {vmax}'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('expression (z-score)', rotation=90, labelpad=3, fontsize=12)

plt.tight_layout()
plt.show()

# %%
vmin = -1.5
vmax = 1.5

cmap = plt.cm.PuOr
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 2.5, 0.88
fig, ax = plt.subplots()

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='horizontal',
    shrink=0.5,
)

cbar.set_ticks([vmin, 0, vmax])
# cbar.set_ticklabels([vmin, f'≥ {vmax}'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('expression (z-score)', rotation=0, labelpad=3, fontsize=12)

plt.tight_layout()
plt.show()

# %%
cmap = plt.cm.gist_heat
norm = mpl.colors.Normalize(vmin=0, vmax=4)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1.05, 2
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([0, 4])
cbar.set_ticklabels(['low', 'high'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('distance', rotation=90, labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
cmap = plt.cm.coolwarm
norm = mpl.colors.Normalize(vmin=0, vmax=1)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 0.8, 2
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([0, 1])
cbar.set_ticklabels([0, 1])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('velocity length', rotation=90, labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()

# %%
cmap = plt.cm.plasma
norm = mpl.colors.Normalize(vmin=0, vmax=1)
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 1.05, 2
fig, ax = plt.subplots()

# ax.axis('off')

cbar = plt.colorbar(
    sm,
    cax=ax,
    orientation='vertical',
    shrink=0.5,
)

cbar.set_ticks([0, 1])
cbar.set_ticklabels(['low', 'high'])
cbar.ax.tick_params(labelsize=12)
cbar.set_label('identity score', rotation=90, labelpad=0, fontsize=12)

plt.tight_layout()
plt.show()
