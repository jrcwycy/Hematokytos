# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns
import yaml
import time

# %% [markdown]
# # Load gene info

# %%
fpath = "../resources/isoform_map.csv.gz"
gdf = pd.read_csv(fpath, low_memory=False)

# 1. Map Gene stable ID → Gene name
gene_map = (
    gdf[['Gene stable ID', 'Gene name']]
    .drop_duplicates()
    .set_index('Gene stable ID')['Gene name']
    .to_dict()
)

# 2. Map Transcript stable ID → Transcript name
transcript_map = (
    gdf[['Transcript stable ID', 'Transcript name']]
    .drop_duplicates()
    .set_index('Transcript stable ID')['Transcript name']
    .to_dict()
)

print(f"{len(gene_map)=}")
print(f"{len(transcript_map)=}")

# examples
print(gene_map.get('ENSG00000150907'))
print(transcript_map.get('ENST00000361390'))

gdf.head()
# Out:
# len(gene_map)=21517
# len(transcript_map)=109780
# FOXO1
# MT-ND1-201
#     Gene stable ID Gene stable ID version Transcript stable ID  \
# 0  ENSG00000198888      ENSG00000198888.2      ENST00000361390
# 1  ENSG00000198763      ENSG00000198763.3      ENST00000361453
# 2  ENSG00000198804      ENSG00000198804.2      ENST00000361624
# 3  ENSG00000198712      ENSG00000198712.1      ENST00000361739
# 4  ENSG00000228253      ENSG00000228253.1      ENST00000361851
#
#   Transcript stable ID version Protein stable ID Protein stable ID version  \
# 0            ENST00000361390.2   ENSP00000354687         ENSP00000354687.2
# 1            ENST00000361453.3   ENSP00000355046         ENSP00000355046.4
# 2            ENST00000361624.2   ENSP00000354499         ENSP00000354499.2
# 3            ENST00000361739.1   ENSP00000354876         ENSP00000354876.1
# 4            ENST00000361851.1   ENSP00000355265         ENSP00000355265.1
#
#    Transcript length (including UTRs and CDS) Transcript name Gene name  \
# 0                                         956      MT-ND1-201    MT-ND1
# 1                                        1042      MT-ND2-201    MT-ND2
# 2                                        1542      MT-CO1-201    MT-CO1
# 3                                         684      MT-CO2-201    MT-CO2
# 4                                         207     MT-ATP8-201   MT-ATP8
#
#   UniProtKB/Swiss-Prot ID UniProtKB/TrEMBL ID
# 0                  P03886              U5Z754
# 1                  P03891              Q7GXY9
# 2                  P00395              U5YWV7
# 3                  P00403              U5Z487
# 4                  P03928              U5YV54

# %% [markdown]
# # Load SUPPA outputs

# %%
dirpath = "/nfs/turbo/umms-indikar/shared/projects/HSC/data/resources/suppa_AS_events/"

file_list = glob.glob(f"{dirpath}/*.ioe*")
file_list
# Out:
# ['/nfs/turbo/umms-indikar/shared/projects/HSC/data/resources/suppa_AS_events/as_events_AF_strict.ioe',
#  '/nfs/turbo/umms-indikar/shared/projects/HSC/data/resources/suppa_AS_events/as_events_MX_strict.ioe',
#  '/nfs/turbo/umms-indikar/shared/projects/HSC/data/resources/suppa_AS_events/as_events_AL_strict.ioe',
#  '/nfs/turbo/umms-indikar/shared/projects/HSC/data/resources/suppa_AS_events/as_events_RI_strict.ioe',
#  '/nfs/turbo/umms-indikar/shared/projects/HSC/data/resources/suppa_AS_events/as_events_A5_strict.ioe',
#  '/nfs/turbo/umms-indikar/shared/projects/HSC/data/resources/suppa_AS_events/as_events_A3_strict.ioe',
#  '/nfs/turbo/umms-indikar/shared/projects/HSC/data/resources/suppa_AS_events/as_events_SE_strict.ioe']

# %%
# from https://github.com/comprna/SUPPA?tab=readme-ov-file#ioe
event_descriptions = {
    "SE": "skipping exon",
    "A5": "alternative 5' splice site",
    "A3": "alternative 3' splice site",
    "MX": "mutually exclusive exon",
    "RI": "retained intron",
    "AF": "alternative first exon",
    "AL": "alternative last exon",
}

# %%
df_list = []

for file_path in file_list:
    basename = os.path.basename(file_path)

    event_type = basename.split("_")[2]
    tmp = pd.read_csv(file_path, sep='\t')
    
    tmp = tmp[['gene_id', 'alternative_transcripts']]
    print(f"raw {tmp.shape=}")
    tmp = tmp.drop_duplicates()
    print(f"raw {tmp.shape=}")

    # 1. split comma-separated strings into lists
    tmp['alternative_transcripts'] = (
        tmp['alternative_transcripts']
        .astype(str)
        .str.split(',')
    )
    
    # 2. explode lists into one row per transcript
    tmp = (
        tmp
        .explode('alternative_transcripts')
        .reset_index(drop=True)
    )
    
    # 3. strip whitespace
    tmp['alternative_transcripts'] = tmp['alternative_transcripts'].str.strip()
    tmp = tmp.drop_duplicates()
    print(f"exploded {tmp.shape=}")

    tmp['event_type'] = event_type
    tmp['event_label'] = event_descriptions[event_type]
    tmp['gene_name'] = tmp['gene_id'].map(gene_map)
    tmp['transcript_name'] = tmp['alternative_transcripts'].map(transcript_map)

    df_list.append(tmp)


df = pd.concat(df_list)
df = df.reset_index(drop=True)

df = df.rename(columns={'alternative_transcripts' : 'transcript_id'})
df = df.drop_duplicates()
print(f"\n{df.shape=}")
print(f"{df['gene_id'].nunique()=}")
print(f"{df['transcript_id'].nunique()=}")
df.head()
# Out:
# raw tmp.shape=(129375, 2)
# raw tmp.shape=(42691, 2)
# exploded tmp.shape=(49294, 2)
# raw tmp.shape=(10227, 2)
# raw tmp.shape=(7989, 2)
# exploded tmp.shape=(13539, 2)
# raw tmp.shape=(44202, 2)
# raw tmp.shape=(19023, 2)
# exploded tmp.shape=(22085, 2)
# raw tmp.shape=(10408, 2)
# raw tmp.shape=(7678, 2)
# exploded tmp.shape=(12655, 2)
# raw tmp.shape=(21380, 2)
# raw tmp.shape=(18411, 2)
# exploded tmp.shape=(41637, 2)
# raw tmp.shape=(23851, 2)
# raw tmp.shape=(20854, 2)
# exploded tmp.shape=(56365, 2)
# raw tmp.shape=(55915, 2)
# raw tmp.shape=(53594, 2)
# exploded tmp.shape=(93377, 2)
#
# df.shape=(288952, 6)
# df['gene_id'].nunique()=19551
# df['transcript_id'].nunique()=149345
#            gene_id    transcript_id event_type             event_label  \
# 0  ENSG00000236601  ENST00000450983         AF  alternative first exon
# 1  ENSG00000236601  ENST00000412666         AF  alternative first exon
# 2  ENSG00000237491  ENST00000655765         AF  alternative first exon
# 3  ENSG00000237491  ENST00000670700         AF  alternative first exon
# 4  ENSG00000237491  ENST00000429505         AF  alternative first exon
#
#   gene_name transcript_name
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3       NaN             NaN
# 4       NaN             NaN

# %% [markdown]
# # transform

# %%
pdf = df.copy()
pdf['value'] = 1
pdf = pd.pivot_table(
    pdf,
    index=['gene_name', 'gene_id', 'transcript_name', 'transcript_id'],
    columns='event_type',
    values='value',
    fill_value=0,
).astype(bool)
pdf['num_events'] = pdf.sum(axis=1)

pdf = pdf.reset_index(drop=False).reset_index(drop=True)
print(f"{pdf.shape=}")
print(f"{pdf['gene_id'].nunique()=}")
print(f"{pdf['transcript_id'].nunique()=}")
pdf.head()
# Out:
# pdf.shape=(63700, 12)
# pdf['gene_id'].nunique()=11279
# pdf['transcript_id'].nunique()=63700
# event_type gene_name          gene_id transcript_name    transcript_id     A3  \
# 0                A2M  ENSG00000175899         A2M-201  ENST00000318602  False
# 1                A2M  ENSG00000175899         A2M-202  ENST00000404455  False
# 2              A2ML1  ENSG00000166535       A2ML1-202  ENST00000536789  False
# 3              A2ML1  ENSG00000166535       A2ML1-205  ENST00000539547  False
# 4              A2ML1  ENSG00000166535       A2ML1-207  ENST00000541459  False
#
# event_type     A5     AF     AL     MX     RI     SE  num_events
# 0           False  False  False  False  False   True           1
# 1           False  False  False  False  False   True           1
# 2            True  False  False  False  False  False           1
# 3           False   True  False  False  False  False           1
# 4           False   True   True  False  False  False           2

# %%
pdf['transcript_name'].value_counts()
# Out:
# transcript_name
# ZZZ3-204     1
# A2M-201      1
# A2M-202      1
# A2ML1-202    1
# A2ML1-205    1
#             ..
# AAR2-201     1
# AAR2-202     1
# AAR2-204     1
# AAR2-205     1
# AAR2-207     1
# Name: count, Length: 63700, dtype: int64

# %% [markdown]
# # Save to file

# %%
outpath = "../resources/AS_events.csv.gz"
pdf.to_csv(
    outpath,
    index=False,
    compression='gzip',
)
print(f"{pdf.shape=}")
pdf.head()
# Out:
# pdf.shape=(63700, 12)
# event_type gene_name          gene_id transcript_name    transcript_id     A3  \
# 0                A2M  ENSG00000175899         A2M-201  ENST00000318602  False
# 1                A2M  ENSG00000175899         A2M-202  ENST00000404455  False
# 2              A2ML1  ENSG00000166535       A2ML1-202  ENST00000536789  False
# 3              A2ML1  ENSG00000166535       A2ML1-205  ENST00000539547  False
# 4              A2ML1  ENSG00000166535       A2ML1-207  ENST00000541459  False
#
# event_type     A5     AF     AL     MX     RI     SE  num_events
# 0           False  False  False  False  False   True           1
# 1           False  False  False  False  False   True           1
# 2            True  False  False  False  False  False           1
# 3           False   True  False  False  False  False           1
# 4           False   True   True  False  False  False           2
